# %%
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.options.mode.chained_assignment = None

# %%
data = pd.read_csv('menu.csv', index_col=0)
data = data.dropna()
data = data.drop_duplicates()
data.columns.tolist()
# Out:
# ['Item',
#  'Serving Size',
#  'Calories',
#  'Calories from Fat',
#  'Total Fat',
#  'Total Fat (% Daily Value)',
#  'Saturated Fat',
#  'Saturated Fat (% Daily Value)',
#  'Trans Fat',
#  'Cholesterol',
#  'Cholesterol (% Daily Value)',
#  'Sodium',
#  'Sodium (% Daily Value)',
#  'Carbohydrates',
#  'Carbohydrates (% Daily Value)',
#  'Dietary Fiber',
#  'Dietary Fiber (% Daily Value)',
#  'Sugars',
#  'Protein',
#  'Vitamin A (% Daily Value)',
#  'Vitamin C (% Daily Value)',
#  'Calcium (% Daily Value)',
#  'Iron (% Daily Value)']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Breakfast to Smoothies & Shakes
# Data columns (total 23 columns):
# Item                             260 non-null object
# Serving Size                     260 non-null object
# Calories                         260 non-null int64
# Calories from Fat                260 non-null int64
# Total Fat                        260 non-null float64
# Total Fat (% Daily Value)        260 non-null int64
# Saturated Fat                    260 non-null float64
# Saturated Fat (% Daily Value)    260 non-null int64
# Trans Fat                        260 non-null float64
# Cholesterol                      260 non-null int64
# Cholesterol (% Daily Value)      260 non-null int64
# Sodium                           260 non-null int64
# Sodium (% Daily Value)           260 non-null int64
# Carbohydrates                    260 non-null int64
# Carbohydrates (% Daily Value)    260 non-null int64
# ...

# %%
data.describe(include='all')
# Out:
#                                   Item  Serving Size     Calories  \
# count                              260           260   260.000000
# unique                             260           107          NaN
# top     Mocha with Nonfat Milk (Small)  16 fl oz cup          NaN
# freq                                 1            45          NaN
# mean                               NaN           NaN   368.269231
# std                                NaN           NaN   240.269886
# min                                NaN           NaN     0.000000
# 25%                                NaN           NaN   210.000000
# 50%                                NaN           NaN   340.000000
# 75%                                NaN           NaN   500.000000
# max                                NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# ...

# %%
data = data.reset_index()
data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat          ...           \
# ...

# %%
df = data[['Category','Item','Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)', 'Dietary Fiber (% Daily Value)']]

fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.corr(), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
df = df[df['Category'] == 'Breakfast']

df = df.groupby(['Category', 'Item']).sum()

df = df.sort_values(by=['Protein'], ascending=False, axis=0)

fig, ax = plt.subplots(figsize=(15, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df = df[df['Category'] == 'Beef & Pork']
df = df[df['Item'] != 'Jalapeño Double']

df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df = df[df['Category'] == 'Chicken & Fish']
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, inplace=True, axis=0)

df = df[df['Category'] == 'Salads']
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, inplace=True, axis=0)

df = df[df['Category'] == 'Snacks & Sides']
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, inplace=True, axis=0)

df = df[df['Category'] == 'Desserts']
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, inplace=True, axis=0)

df = df[df['Category'] == 'Beverages']
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)
fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, inplace=True, axis=0)

df = df[df['Category'] == 'Coffee & Tea']
df = df[~df['Item'].str.contains('Frappé')]
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)

fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Carbohydrates', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
           'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]

df = df[df['Category'] == 'Smoothies & Shakes']

# removing because of encoding issue
df = df[~df.Item.str.contains('M&M\’s')]
df = df.groupby(['Item']).sum()
df = df.sort_values(by=['Carbohydrates', 'Sugars', 'Protein'], ascending=False, axis=0)

fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.head(10), ax=ax, annot=True)

# %%
df = data[['Category','Item', 'Calories from Fat', 'Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)',
           'Cholesterol (% Daily Value)', 'Sodium', 'Dietary Fiber (% Daily Value)', 'Carbohydrates']]

fig, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(df.corr(), annot=True, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(15, 9))
sns.heatmap(data.corr(), ax=ax, annot=True)

# %%
data.groupby(['Category', 'Item'])['Protein'].mean()
# Out:
# Category            Item
# Beef & Pork         Bacon Clubhouse Burger                               39
#                     Bacon McDouble                                       27
#                     Big Mac                                              24
#                     Cheeseburger                                         15
#                     Daily Double                                         22
#                     Double Cheeseburger                                  24
#                     Double Quarter Pounder with Cheese                   48
#                     Hamburger                                            12
#                     Jalapeño Double                                      22
#                     McDouble                                             22
#                     McRib                                                22
#                     Quarter Pounder Deluxe                               29
# ...
